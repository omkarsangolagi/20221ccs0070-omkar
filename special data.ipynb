# %%
# !pip install folium

# %%
import folium
mymap = folium.Map(location = [12.972442, 77.580643],
                   width = 950,
                   height = 550,
                   zoom_start = 12,
                   tiles = 'openstreetmap')
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
marker1 = folium.Marker([13.173042, 77.563631], popup='My city')
marker2 = folium.Marker([13.173662, 77.531512], popup='My pg')
marker3 = folium.Marker([13.170567, 77.535997], popup='My university')
marker4 = folium.Marker([13.097402, 77.591630], popup='nes bus stop')
marker5 = folium.Marker([13.102099, 77.592505], popup='railway station')
marker1.add_to(mymap)
marker2.add_to(mymap)
marker3.add_to(mymap)
marker4.add_to(mymap)
marker5.add_to(mymap)

mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium
bangalore_coords = (12.972442, 77.580643)
map_bangalore = folium.Map(location=bangalore_coords, zoom_start=12)
places = {
    "presidency university":(13.170567, 77.535997),
    "NES bus stop":(13.097402, 77.591630),
    "My pg":(13.173662, 77.531512),
    "yalahanka railway station":(13.102099, 77.592505),
    "cubbon park":(12.977683, 77.595262),
    "iskon temple":(13.009736, 77.550844)
}

# %%
images = {
    "presidency university":"https://lh5.googleusercontent.com/p/AF1QipNHb_LbwZC5xaYo-RAp0xKK-xp2AqK4chhbDPQ6=w408-h272-k-no"
    "NES bus stop":"https://lh5.googleusercontent.com/p/AF1QipNGfJJRzVV_jsmobutjUFa4A7bBE-dSH7q2tzE7=w408-h544-k-no"
    "My pg":"https://lh5.googleusercontent.com/p/AF1QipMOoDPdADpowsFyDbNVfMtbcXvGAHtC-3H6pJ_C=w408-h544-k-no"
    "yalahanka railway station":"https://lh5.googleusercontent.com/p/AF1QipOckw6O3A14p2Ofx1dtFwnTECgsR3fkloHBn8RA=w426-h240-k-no"
    "cubbon park":"https://lh5.googleusercontent.com/p/AF1QipPfcKdZHlQ3d9oDK6QBSC26HOVtUXvSpu18O8lW=w408-h306-k-no"
    "iskon temple":"https://lh5.googleusercontent.com/p/AF1QipNeKqEmbE6lrwAH8iVr-gJj5yzjL3-xo2-95oLp=w408-h725-k-no"

}
for place,coords in place.items():
  popup_content=f'<b>
  folium.Marker(location=coords, popup=folium.Popup(popup_content, max_width=300)).add_to(map_bangalore)
map_bangalore
# Out:
#   File "<ipython-input-22-43067f2c821a>", line 11
#     popup_content=f'<b>
#                   ^
# SyntaxError: unterminated string literal (detected at line 11)
